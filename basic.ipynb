# %%
"this is a test" + chr(0) + "string"
# Out:
# 'this is a test\x00string'

# %%
print("this is a test" + chr(0) + "string")
# Out:
# this is a teststring

# %%
def decode_utf8_bytes_to_str_wrong(bytestring: bytes):
    return "".join([bytes([b]).decode("utf-8") for b in bytestring])


b"\x21".decode("utf-8")
# Out:
# '!'

# %%
a = [1,2,3]
b=[4,5]
c=zip(a,b)
for a in c:
    print(a)
# Out:
# (1, 4)
# (2, 5)

# %%
a=[1,2,3]
b=[4,5]
del a[0]
a
# Out:
# [2, 3]

# %%
import os

os.cpu_count()
# Out:
# 14

# %%
# !pwd
# Out:
# /Users/while/Desktop/cs/336/basics/assignment1-basics
# python(57972) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.

# %%
from cs336_basics.pretokenization_example import find_chunk_boundaries

with open("data/TinyStoriesV2-GPT4-train.txt", "rb") as f:
        boundaries = find_chunk_boundaries(f, 10, b"<|endoftext|>")

boundaries
# Out:
# [0,
#  222775475,
#  445550788,
#  668326482,
#  891101671,
#  1113876594,
#  1336652984,
#  1559427993,
#  1782202745,
#  2004978648,
#  2227753162]

# %%
327680000/32/256
# Out:
# 40000.0

# %%
for i in range(3):
    print(i)
print(i)
# Out:
# 0
# 1
# 2
# 2

# %%
import torch
torch.Tensor([[1,3]]).shape
# Out:
# torch.Size([1, 2])

# %%
try: 
    import torchinfo
except:
    # !pip install torchinfo
    import torchinfo
    
from torchinfo import summary
from assignment.part2.all import transformer_lm
import torch
module = transformer_lm(
        10000, 256, 512, 4, 16, 1344, 10000
    ).to("mps")

print(module)
# summary(module,
#         input_size=(32, 256),
#         dtypes=[torch.long],     # token IDs, not floats
#         device="mps")
# Out:
# transformer_lm(
#   (embedding): Embedding()
#   (attns): ModuleList(
#     (0-3): 4 x transformer_block(
#       (norm1): Rmsnorm()
#       (mulatt): multihead_self_attention(
#         (rope): Rope()
#       )
#       (norm2): Rmsnorm()
#       (pffn): Pffn()
#     )
#   )
#   (norm): Rmsnorm()
#   (linear): Linear()
#   (softmax): Softmax()
# )
